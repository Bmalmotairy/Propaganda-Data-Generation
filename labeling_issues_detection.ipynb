# %%
import optuna
import numpy as np
import pandas as pd
from cleanlab import Datalab

optuna.logging.set_verbosity(optuna.logging.WARNING)

# %%
from sklearnex import patch_sklearn

patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# %%
import fasttext
from tqdm.auto import tqdm

encoder = fasttext.load_model("./encoders/cc.ar.300.bin")
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
dataset = pd.read_excel("./data/to_label.xlsx", sheet_name="Sheet1")
dataset["label"] = dataset["label"].astype(int)
dataset.head()
# Out:
#                tweetid                                         tweet_text  \
# 0   295735762505322497  النعيم أمي، وعين أمي، وقبلة أمي، فأكرمها يالله...
# 1  1080873494227886086  RT @rood516: عرض الاجازه😍👌🏻1\nســــاعه\nقـــلم...
# 2  1027481525506453504  RT @6FSH1_: مهما ضاق صدرك تذكر أن في ناس توهم ...
# 3   417202038037299200  RT @f450450: ﴿ياحي ياقيوم برحمتك أستغيث أصلح ل...
# 4   834074569673736193  RT @7744Qa: بعض البشر ، إذا وجد البديل نكر الج...
#
#                                          clean_tweet tech  label
# 0  النعيم أمي، وعين أمي، وقبلة أمي، فأكرمها يالله...  NaN      0
# 1  RT : عرض الاجازه1 ســــاعه قـــلم كــبك نظـــا...  NaN      0
# 2  RT : مهما ضاق صدرك تذكر أن في ناس توهم بيسجلون...  NaN      0
# 3  RT : ﴿ياحي ياقيوم برحمتك أستغيث أصلح لي شأني ك...  NaN      0
# 4  RT : بعض البشر ، إذا وجد البديل نكر الجميل. قر...  NaN      0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2100 entries, 0 to 2099
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tweetid      2100 non-null   int64
#  1   tweet_text   2100 non-null   object
#  2   clean_tweet  2100 non-null   object
#  3   tech         202 non-null    object
#  4   label        2100 non-null   int32
# dtypes: int32(1), int64(1), object(3)
# memory usage: 74.0+ KB

# %%
tweets = dataset.clean_tweet.to_list()
labels = dataset.label.values

# %%
features = []

for tweet in tqdm(tweets):
    features.append(encoder.get_sentence_vector(tweet))
# Out:
#   0%|          | 0/2100 [00:00<?, ?it/s]

# %%
data = {"X": np.array(features), "Y": labels}

# %%
w = dataset.label.value_counts(normalize=True).to_list()
w = {i: w[i] for i in range(len(w))}
w
# Out:
# {0: 0.9038095238095238, 1: 0.09619047619047619}

# %%
x_train, x_test, y_train, y_test = train_test_split(
    data["X"], data["Y"], test_size=0.25, stratify=data["Y"], random_state=42
)

# %%
def objective(trial):
    p = trial.suggest_categorical("penalty", ["l1", "l2"])
    s = trial.suggest_categorical("solver", ["liblinear"])
    c = trial.suggest_categorical("C", [0.1, 1.0, 10.0, 100.0, 1000.0])
    model = LogisticRegression(
        penalty=p, solver=s, C=c, class_weight=w, max_iter=1000, random_state=42
    )
    model.fit(x_train, y_train)
    # acc = model.score(x_test, y_test)
    f1 = f1_score(y_test, model.predict(x_test), average="binary")
    return f1

# %%
study = optuna.create_study(
    study_name="propaganda cleaning",
    direction="maximize",
    storage="sqlite:///propaganda.db",
    load_if_exists=False,
)

study.optimize(objective, n_trials=1000, n_jobs=-1, show_progress_bar=True)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
study.best_params
# Out:
# {'penalty': 'l1', 'solver': 'liblinear', 'C': 1000.0}

# %%
model = LogisticRegression(
    class_weight=w, random_state=42, max_iter=1000, **study.best_params
)
pred_probs = cross_val_predict(
    estimator=model, X=data["X"], y=data["Y"], cv=50, method="predict_proba"
)

# %%
lab = Datalab(data, label_name="Y")
lab.find_issues(pred_probs=pred_probs, features=data["X"])
# Out:
# Finding label issues ...
# Finding outlier issues ...
# Fitting OOD estimator based on provided features ...
# Finding near_duplicate issues ...
# Audit complete. 296 issues found in the dataset.

# %%
lab.report()
# Out:
# Here is a summary of the different kinds of issues found in the data:
#
#     issue_type  num_issues
#          label         209
# near_duplicate          46
#        outlier          41
#
# Dataset Information: num_examples: 2100, num_classes: 2
#
#
# ----------------------- label issues -----------------------
#
# About this issue:
# 	Examples whose given label is estimated to be potentially incorrect
#     (e.g. due to annotation error) are flagged as having label issues.
#
#
# Number of examples with this issue: 209
# Overall dataset quality in terms of this issue: 0.8914
#
# Examples representing most severe instances of this issue:
#       is_label_issue   label_score  given_label  predicted_label
# 1715            True  0.000000e+00            0                1
# 502             True  0.000000e+00            0                1
# 284             True  0.000000e+00            0                1
# 2028            True  0.000000e+00            0                1
# 373             True  2.920535e-13            1                0
#
#
# ------------------ near_duplicate issues -------------------
#
# About this issue:
# 	A (near) duplicate issue refers to two or more examples in
#     a dataset that are extremely similar to each other, relative
#     to the rest of the dataset.  The examples flagged with this issue
#     may be exactly duplicated, or lie atypically close together when
#     represented as vectors (i.e. feature embeddings).
#
#
# Number of examples with this issue: 46
# Overall dataset quality in terms of this issue: 0.2115
#
# Examples representing most severe instances of this issue:
#       is_near_duplicate_issue  near_duplicate_score                                  near_duplicate_sets  distance_to_nearest_neighbor
# 1989                     True              0.003737                               [1649, 860, 552, 1520]                      0.003737
# 1649                     True              0.003737                                     [1989, 860, 552]                      0.003737
# 400                      True              0.005607                                               [1718]                      0.005607
# 1718                     True              0.005607                                                [400]                      0.005607
# 1452                     True              0.010401  [1117, 766, 867, 851, 430, 1020, 25, 915, 948, 739]                      0.010402
#
#
# ---------------------- outlier issues ----------------------
#
# About this issue:
# 	Examples that are very different from the rest of the dataset
#     (i.e. potentially out-of-distribution or rare/anomalous instances).
#
#
# Number of examples with this issue: 41
# Overall dataset quality in terms of this issue: 0.7762
#
# Examples representing most severe instances of this issue:
#       is_outlier_issue  outlier_score
# 937               True       0.520760
# 925               True       0.521811
# 744               True       0.535892
# 1533              True       0.568117
# 1239              True       0.575193

# %%
pd.set_option("display.max_colwidth", None, "display.max_rows", None)

# %%
issues = lab.get_issues()

# %%
issues.head()
# Out:
#    is_label_issue  label_score  is_outlier_issue  outlier_score  \
# 0           False     0.999725             False       0.720818
# 1           False     1.000000             False       0.808768
# 2           False     0.999028             False       0.757022
# 3           False     0.999994             False       0.785526
# 4           False     1.000000             False       0.854087
#
#    is_near_duplicate_issue  near_duplicate_score
# 0                    False              0.272238
# 1                    False              0.178953
# 2                    False              0.259652
# 3                    False              0.128088
# 4                    False              0.120545

# %%
label_issues = dataset[issues.is_label_issue]
label_issues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209 entries, 14 to 2087
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tweetid      209 non-null    int64
#  1   tweet_text   209 non-null    object
#  2   clean_tweet  209 non-null    object
#  3   tech         116 non-null    object
#  4   label        209 non-null    int32
# dtypes: int32(1), int64(1), object(3)
# memory usage: 9.0+ KB

# %%
label_issues.head(100)
# Out:
#                  tweetid  \
# 14    691276323428282368
# 28    851516912924340224
# 34   1137141663397269505
# 41   1052603026425487360
# 65   1098592460069105664
# 68    460142383833681920
# 102   784479049053827072
# 125  1020854328804937730
# 133   981562439757189126
# 135   656822170132176896
# 142   694186570182688768
# 146   674574426785120256
# 150   782937534116560896
# 153   700665761845657600
# 170  1079428303969226752
# 172  1180389807073177600
# 187   747246890178215940
# 189   862396856130838528
# 203   565817726656983040
# 204   963058318452383744
# 206   791386956416552960
# 211   945264303745257472
# 213  1053786447516450816
# 233  1051613169641287680
# 246   768499364226629632
# 257  1057380347174891520
# 260  1059078776737423360
# 272   928373794502316033
# 273   736014190419267584
# 277   792866057073688577
# 282  1101078584142282752
# 284  1010920563626438656
# 295   926520205546807296
# 301  1057511353072734213
# 302  1073947566591696897
# 310  1176320376948887552
# 322  1087561555254882304
# 329  1092116720226127875
# 330   678696420132716545
# 360   852263826389168128
# 372   520300665780699137
# 373  1119981960900878336
# 382   625599222788702208
# 386  1055504030003269632
# 409  1105768163076128768
# 413   466996015027867648
# 424   997047670643527680
# 444   915906972058374144
# 465   673289393164173312
# 468  1045309687518908416
# 469   814196918729539585
# 476   350647457627119619
# 477  1020403185427668992
# 478   963394946375016448
# 486   846583179544842240
# 490   668581428142190592
# 502  1158948463679279104
# 504  1071690186801758208
# 507   616377723498295296
# 515  1001547238106157056
# 521  1161014740329648128
# 522  1100336063854239744
# 527   824940133371768832
# 534  1157410291778555905
# 544  1105465118027059202
# 556   399885755520405504
# 561   908623086865588224
# 586   768951335416922113
# 593  1041048360579424257
# 595   994306208252166144
# 606   463261865016307712
# 607   914002034629718016
# 623  1054352697271508993
# 633   856775000321392640
# 634  1143846495529164800
# 650   346687005725454336
# 658  1081587621934043137
# 663  1094533355037777920
# 673   809028766324363264
# 677   645148590193569792
# 679   404263839996592128
# 748  1009384845548621825
# 749   541243365568696321
# 755  1110463003063918593
# 756  1101120404716994560
# 760   391365739006803968
# 764  1083098291586387972
# 767  1081921883992403968
# 807   872264738889240580
# 809   920456839912939521
# 865  1034682366613233664
# 872   571099945970741248
# 877   501332582626127872
# 878   913174571813101569
# 886  1088837894335352832
# 889   517420863621066752
# 896   342299862429229056
# 911   653981102311350272
# 912  1161807633675902976
# 924   864863636778618881
#
#                                                                                                                                                                                   tweet_text  \
# 14                                                                                                                                                    كوريا اكتشافي بدا الكل يمدحه .. روووعة
# 28                                             سجل يا تاريخ واحفظها يا تاريخ النصر\nلاول مرة منذ تأسيس نادينا\nاصبحنا كوشه لنادي الهلال\nبسبب فكر رئيس مايعرف من كرة القدم\nالا ميسي وحسين 😂
# 34                                                                         RT @ryadygadeem: #AlhilalwantsFifaToSavehim3\nونستمر في هذي الحمله المليونيه لأجل الهلال💪 https://t.co/T434ilELwS
# 41                                                                      RT @yi4_5: #المصمم_دافي_العتيبي_مبدع\n#همس_الغلا_مصممه_مبدعه\n\nيستاهلون الترند  سما سما 🚀🚀🚀 https://t.co/fgIOXxqJQY
# 912                                                                                                    لَيْتَ مَا فِي القُلُوبِ يُرَى كَيْ لَا يُسَاءُ فَهْمِنَا وَلَا نُسِيءُ فَهْمَ أَحَدٍ
# 924                                                                                                              RT @yooyo639: #سعوديه_وساقود_سيارتي_بنفسي315\nسعوديه_وساقود_سيارتي_بنفسي315
#
#                                                                                                                                                                              clean_tweet  \
# 14                                                                                                                                                كوريا اكتشافي بدا الكل يمدحه .. روووعة
# 28                                               سجل يا تاريخ واحفظها يا تاريخ النصر لاول مرة منذ تأسيس نادينا اصبحنا كوشه لنادي الهلال بسبب فكر رئيس مايعرف من كرة القدم الا ميسي وحسين
# 34                                                                                                            RT : AlhilalwantsFifaToSavehim3 ونستمر في هذي الحمله المليونيه لأجل الهلال
# 41                                                                                                           RT : المصمم دافي العتيبي مبدع همس الغلا مصممه مبدعه يستاهلون الترند سما سما
# 65                                                                                                                                                     راشد الماجد سايحون رررغم الطناطير
# 68                                                                                                     شرطة منطقة الرياض توقع بعصابة سرقة السيارات تحت تهديد السلاح مؤلفة من ثلاثة أشخاص
# 102                                                                                                                              RT : الاب يصنع المستحيل في اقسى الظروف من اجل أطفاله ..
# 125                                                                                                                                         ربي آغفرلي وآرحمني كلنا مع عبدالعزيز الجبرين
# 133                                                                    RT : الشرع محلل اربع كلنا المريسل المدينة المنورة مكة المكرمة جده ينبع الصناعية ينبع تبوك لمن يبحث عن جودة العسل…
# 135                                                                                                                                     RT : كاريكاتير .. المسيرة الشيطانية مرت من هنا !
# 142                                                        عوده عبدالكريم الحربي للقريه سألوها ما رأيك بالحجاب..! فقالت: يكفينا شرفا أننا إذا مررنا بزحام فتحوا لنا طريقا كالأميرات &lt;
# 146                                                                                                                                           التحذير من البردة وما فيها من شركيات ( 1 )
# 150                                                                                                                                      RT : انت راعي الاوله يبو مشعل يستاهلون متابعينك
# 153                                                                                                           RT : الدجه وماتسوي اتوقع يسحونه بعد فتره ويجبون كانافارو لئن الاعبين يبونه
# 170                                                      RT : زكي الصالح بديلا لموسى المحياني" على الاهلاويين ان لا يحكمو عليه إلا بعد يشوفو عمله الله يوفقه مع الاهلي مفروض الكل يقف م…
# 172                                                                                                                                                    RT : سعود الصرامي متحدثهم يقول !!
# 187                                                                                                                                         RT : نعم نجوم حول ميسي قالها حمار وصدقها جحش
# 189                                                        RT : نبارك لـ سعادة المقدم / نايف بن عايض الجباري القثامي بمناسبة ترقيته نسأل الله أن تكون عونا له لخدمة دينه ومليكه ووطنه .…
# 203                                                   RT : كل نبض في خفوقي لو نطق قال الهلال وكل دم في عروقي أزرق ويا للجمال الهلالي وش عليه ياخذ اللي هو يبيه بالفرح عايش حياته والبطو…
# 204                                      عندما كان سامي يدرب الوحده تلصق بالهلاليين عشان رتويت يوم سامي طلع تلصق بالعيناويه ويطلع اشاعات ان عمر بيجي الهلال عشان رتويت يتغذى رتويت الاخو
# 206                                                                                                                                  تكفون رايد لا يقصونه اللهم سخر له من عبادك المخلصين
# 211                                                                                                                             انت بحاجه للخلافات لمعرفه مايخفيه الاخرون بوحسن للنظارات
# 213                                                                                              RT : البلطان ينتقد بقوه ارضية ملعب الملز يارجل هذا افضل ملعب بالشرق الأوسط الهلال النصر
# 233                                                                                                           RT : معلومات جديدة عن مسرب الأخبار الزائفة حول خاشقجي، المدعو خالد صفوري .
# 246                                                                    RT : ذكرى اعتزال سامي الجابر آخر هدف للمنتخب في كأس العالم سجله سامي الجابر ومن بعد اعتزاله انتهى المنتخب السعودي
# 257                                                                                                                              يا مقلب القلوب ثبت قلبي على دينك حزززب الله يختطف لبنان
# 260                                                                                                                                    RT : AS | ليو ميسي سوف يسافر مع الفريق إلى ميلانو
# 272                                                                                                                           RT : انشهد حب الوطن وبسسس لبيه ي يالعلم ابوفهد لاخلا ولاع…
# 273                                                                                                                                             مشكلات فرنسا تخيم على أكبر بطولات اليورو
# 277                                                                                                                                                  قناة المجد تثير الفتنه والعياذ بلاه
# 282                                                                                         RT : ويك اند جميل وسعيد ع الجميع الايفنت الاكثر من رائع xjed على واجهة جده البحريه مكان رائع
# 284                                                                                                                                                                             غير صحيح
# 295                                                                                                  ياسر القحطاني ضمن ال50 عالميا تصريح تاريخي .. كوزمين س اعتمد ..ع ياسر ولو بقدم وحده
# 301                                                                                                                  RT : عطنا صوره لجو مدينتك ما بعد المدينه مدينه ولا بعد المدينه جمال
# 302                                                                                                                            اللهم أعذنا من عذاب القبر وعذاب جهنم سعوديون فخورون بوطنا
# 310                                                      RT : الرئيس الفرنسي ماكرون يمد يديه وهو جالسا على الكرسي أثناء مصافحة الشيخ تميم بن حمد أمير قطر ، دون مراعاة لبروتوكول مصافحة…
# 322                                                                             في تحدي ال10 سنوات. تشيلسي يتفوق على مان يونايتد والسيتي وارسنال وليفربول وتوتنهام بعدد الالقاب. الديربي
# 329                                                                                                                            خالد الحدي لن تصبح علي سعيد الكعبي توقف عن ذلك .. أرجوك !
# 330                                                                                                                                               RT : ببقى أحبك بالخفى. حب العلن م يدوم
# 360                                                                      كريستيانو قبل التوقيع مع الريال : سوف أثبت لكم بأن القرار الذي اتخذتموه صحيحا - الان كريستيانو ختم جميع الأرقام
# 372                                              فلكة لطفل الخمسة أشهر عسى هالفيديو يبقى طول العمر عشان الطفل هذا يشوفه اذا كبر ويعرف مشاعر ابوه تجاهه وهو بعمر الخمس شهور هو اللي بيحكم
# 373                                                                                                                                     RT : وتستمر الخطوط الجوية القطرية بحصد الجوائز..
# 382                                                                                                                                 RT : ❖ «مونتاري اتحادي» نشط الآن : عبر الأبرز الأنشط
# 386                                                                             RT : تجمع محبي القهوه جده بالليل مطر مع فنجال هيل جده الصباح أجواء نعيم و قهوتي و يارب .... فرحة وإنشراح
# 409                                                                                                                                                          عامر بالايمان قلبك ماذا فيه
# 413                                                                                                                             RT : الناضج .. فن الضيافة وروعة المذاق. الناضج أطعم لك -
# 424                                                                                                                                          RT : اعلان زين استغفرالله العظيم وأتوب إليه
# 444                                                                                       راصد24 . - الملك سلمان : نؤكد على أهمية الحفاظ على وحدة العراق وسلامة جبهته الداخلية . روسيا .
# 465                                                                                                   RT : = سيريزو درب ايضا . حظ هذا المنتخب انه يقاوم شراسة باولو روسي ولا استبسال زوف
# 468                                                                                                                                  اللهم لاتؤاخذنا ان نسينا او اخطأنا لسنا جمهورية موز
# 469                                                                  RT : ومن الأسباب التقليد الأعمى لكل ما يبثه الفساق والكفار، من خلال الأفلام والمسلسلات الهابطة تخيل تخطب وتطلع بويه
# 476                                                                                                                    RT : صدام حسين (صدام حسين من الزنزانة الأمريكية) هذا ماحدث.. (66)
# 477                                                                                               واتساب يكافح الخداع الإلكتروني بميزة جديدة منتظرة - - صحيفة حباشة الإلكترونية العرضيات
# 478  الهلال العين البدايات دائما مهمه , مابالك و أنت تبدأ إستحقاق آسيوي أمام خصم بقيمة العين فريق معروف وهو الأصعب بالمجموعة الاستقلال والريان حتما لن يكونوا خصوما عاديين سيقاتلون ! ..
# 486                                                                                                                                           غلاف i البرتغالية | البطل يعود إلى الوطن .
# 490                                              الاتحاد حقق : -كاس اسيا مرتين -شارك في كاس العالم -حقق الدوري -كاس ولي العهد -كاس الملك كل البطولات ويجي واحد ماحقق اسيا ولا دوري يطقطق
# 502                                                                                                                                                          تخصص لغه عربيه تعالوا ابيكم
# 504                                                                                                                                        RT : الزعيم .. وسر التفوق الهلال النصر الهلال
# 507                                                                                                                                                            الإباضية لا يؤمنون بالسنة
# 515                                                                                                                               لا اله الا الله محمد رسول الله ايران تعبث بأمن المنطقة
# 521                                                               RT +PdT29TXYcj0BcTvBDX0=: بعض المجنسين ( وسخوا البلد ) الله يطهر البلد وينظفه منهم كانوا لاشي (ونظفناهم) ونسيوا أنفسهم
# 522                                                       RT : نشاطنا الرائد في مجالي دراسة الماجستير والدكتوراه منحنا المعرفة في مجالات البحث العلمي الحديثة وغير المستهلكة. جامعة الم…
# 527                                                                   الاردايس: ”هناك العديد من الصفقات التي نتمنى حسمها. وهناك العديد من الصفقات التي حاولنا حسمها ولكننا أخفقنا فيها.”
# 534                                                                                                                                                               RT : احيوا سنة التكبير
# 544                                                            RT : بوتفليقه لا لتمديد العهدة الرابعة ايها الجزائريون الشرفاء: اقسم بالله مادخلت قطر في بلد عربي الا ودمرته واحرقته وجع…
# 556                                                                                                   اللهم اغفرلي كل ذنب فعلته وكل محرما رايته وكل مكروه سمعته يا رب العالمين =&gt;&gt;
# 561                                                                               RT : اللهم انصر مسلمى سوريا وفلسطين والعراق واليمن وليبيا ومصر اللهم انصر مسلمى بورماعلى أعدائك وثبتهم
# 586                                                                                                   RT : المتهم بخطف رجال الأعمال «آل سند» في مصر يقتل نفسه أثناء التحقيق مصر السعودية
# 593                                               RT =: خميسسس هو اللي طير سيرا وجاب دياز والحين النهايه فيلا دكه هذا اللي يبيه الاتحاد م يحتاج افضل من سييرا الاتحاد يحتاج خروجك منه ي…
# 595                                                                 RT : جنودنا دروع الوطن قالوا تغزل قلت في جندي بطل يحمي بلاده ما يهاب المعتدين ننثر له ورود المحبه والنفل ونطلب الله…
# 606                                                                                                                                                                “ سبحان الله وبحمده ”
# 607                                                                                      RT : طيب ليه تلعن امهاتهم؟ عندك رأي اطرحه بكل أدب لاكن تعتدي على المسلمين هذا غير مقبول نهائيا.
# 623                                                                                                            RT : كل التوفيق لجميع الأندية وعلى رأسهم نادي الهلال دعم محمد الفيصل مطلب
# 633                                                                                                                                        المقطع الي لو اتابعة مليون مره مستحيل امل منة
# 634                                                                                                                                                    RT =: افضل صوره التقطتها في حياتي
# 650                                                                                                                                                   حلقة داوود الشريان موولعه هههههههه
# 658                                                                                                                اللهم إنك عفو كريم تحب العفو فاعف عني قطر لاتستطيع تنظيم كاااس العالم
# 663                                                                                                                                          RT : = السعايدة مسخرة وين مايروحوا الحمضيات
# 673                                                      RT : عندما تترك اخا لك تأكله الذئاب ولا تتحرك فاعلم ان الذئاب ستجوع يوما ما وسيكون اخاك ميتا لا يستطيع ان ينقذك حلب تباد بسكوت…
# 677                                                                                                                                         لوثار ماثيوس يحمل قميص ريال مدريد رياضي قديم
# 679                                                                                          RT : ترقبو هذا الفيديو غذا لشرح استعدادات مجلس الجماهير على حساب مجلس الجماهير في التويتر …
# 748                                                    RT : ماني حزين الا على الامير محمد بن سلمان حضر وتعنى وما حصل رجال يقدرون ويقتلون من اجل الوطن ظهور غير مشرف انصاف الرجال لايستح…
# 749                                                                       : جمهور الهلال يشكر فيصل بن تركي مهما فعل لن انسى اتهامه لياسر بالمنشطات لاكن شكرا ع وقفته اليوم ياسر القحطاني
# 755                                                  RT : 09 خاصة بعد أن بلغ الآن ذروة نفوذه بسبب تلاعبه في الانتخابات النيابية، فتمكن من السيطرة على البرلمان اللبناني، وفرض تشكيل الح…
# 756                                                 الأمير تركي بن طلال أمير منطقة عسير يستمع لمطالب أهالي طريب ويدشن عددا من المشاريع التنموية بالمحافظة ومركز الصبيخة التابع للمحافظة.
# 760                                                                                                                                                        انظار الهلاليين تقع على الوسط
# 764                                                          RT : مارتن غريفيث يمثل العقلية البريطانية،التي ساهمت بدفع هتلر لشن الحرب،لإجبارها الحكومة التشيكية على قبول إنذار هتلر،وبذ…
# 767                                                                                                                         لا حول ولا قوة إلا بالله العلي العظيم الاستيناف حكمت القفاري
# 807                                                      RT : نصيحة: إذا لم تكن مسؤولا سياسيا فخير لك الصمت أو تدعوا بالخير لوطنك وأمتك..الحدث جلل السخريه والشتم ليست من شيمنا قطع الع…
# 809                                                            RT : تخفيضات كبرى ٢ ساعه رجالي شبك حصيره سواره رجالي الضمان يشمل لمده سنه كامله السعر شامل التوصيل السعر ٢٣٠ ريال للتواص…
# 865                                    نونو سانتو بعد تأهل الوولفز امام شيفيلد نحن راضون تماما وهنالك أمور ايجابية كثيرة والأهم هو أن الفريق نافس بشكل ممتاز ولا يملكون شيئ ليثبتوه لأحد
# 872                                                                                                  RT : هذا الرجل أشغل الأمة البريطانية وأقلقها على سلامة عملها ضد الإرهاب. عاصم قريشي
# 877                                                                                                             الإنتقاد ليس عيبا , العيب هو أن تنتقد وأنت تفعل نفس ما تنتقده في الناس !
# 878                                                        RT : تمثيل وطني مشرف يقدمه الهلال أداء وتكتيكا فنيا عاليا في المباراة ألف مبروك لجماهير الموج الأزرق وللوطن الغالي كل الأفرا…
# 886                                                                                                        الله لا يبلانا لا تحاربون الله بالمجاهرة بالمعاصي فلكم في الامم السابقة العبر
# 889                                                           RT : جولة تفتيشية مفاجئة لرئيس بلدية الدلم المهندس فارس بن محمد القحطاني تغلق أربعة مطاعم لعدم الالتزام بالاشتراطات الصحية
# 896                                                               مونتي : اللاعبون اتصلوا ب غالياني من اجل بقاء اليغري ؟ لااعتقد .. غالياني وبيرلسكوني اخذ رايهم بحرية وهم يعرفون قرارنا
# 911                                                                                                   RT : طفل جدة.. ذهب إلى مدرسته حيا وعاد جثة هامدة وفاة طفل نسي في حافلة مدرسة جدة -
# 912                                                                                                                               ليت ما في القلوب يرى كي لا يساء فهمنا ولا نسيء فهم أحد
# 924                                                                                                                     RT : سعوديه وساقود سيارتي بنفسي315 سعوديه وساقود سيارتي بنفسي315
#
#                                                       tech  label
# 14                          loaded language - name-calling      1
# 28                     flag-waving - name-calling - smears      1
# 34                                                     NaN      0
# 41                                                     NaN      0
# 65                                                     NaN      0
# 68                                                     NaN      0
# 102                                                    NaN      0
# 125                                            flag-waving      1
# 133                                            flag-waving      1
# 135                         name-calling - loaded language      1
# 142                                        loaded language      1
# 146                               smears - loaded language      1
# 150                                                    NaN      0
# 153                         loaded language - name-calling      1
# 170                                            flag-waving      1
# 172                                                    NaN      0
# 187                         name-calling - loaded language      1
# 189                                                    NaN      0
# 203                                        loaded language      1
# 204                               smears - loaded language      1
# 206          thought-terminating cliche - loaded language       1
# 211                                                    NaN      0
# 213                                           exaggeration      1
# 233                loaded language - name-calling - smears      1
# 246                           loaded language - glittering      1
# 257                smears - name-calling - loaded language      1
# 260                                                    NaN      0
# 272                              name-calling - glittering      1
# 273                                  smears - exaggeration      1
# 277                smears - name-calling - loaded language      1
# 282                         exaggeration - loaded language      1
# 284                                                    NaN      0
# 295            name-calling - loaded language - glittering      1
# 301                         exaggeration - loaded language      1
# 302                                            flag-waving      1
# 310                               smears - loaded language      1
# 322                         loaded language - name-calling      1
# 329                                                    NaN      0
# 330                                                    NaN      0
# 360                                    appeal to authority      1
# 372                                        loaded language      1
# 373                         name-calling - loaded language      1
# 382                                                    NaN      0
# 386                         name-calling - loaded language      1
# 409                                                    NaN      0
# 413                                                    NaN      0
# 424                                                 smears      1
# 444                                                    NaN      0
# 465                                                    NaN      0
# 468                                            flag-waving      1
# 469                               loaded language - smears      1
# 476                                                    NaN      0
# 477                         loaded language - name-calling      1
# 478                         exaggeration - loaded language      1
# 486                         name-calling - loaded language      1
# 490                                        loaded language      1
# 502                                                    NaN      0
# 504                                                    NaN      0
# 507                                  name-calling - smears      1
# 515                                                 smears      1
# 521                          loaded language - flag-waving      1
# 522                                        loaded language      1
# 527                                                    NaN      0
# 534                                                    NaN      0
# 544  flag-waving - dictatorship - loaded language - smears      1
# 556                                                    NaN      0
# 561                                                    NaN      0
# 586                                                    NaN      0
# 593                                                 smears      1
# 595                                             glittering      1
# 606                                                    NaN      0
# 607                                            flag-waving      1
# 623                                            flag-waving      1
# 633                                                    NaN      0
# 634                                                    NaN      0
# 650                                                    NaN      0
# 658                                                 smears      1
# 663                                                    NaN      0
# 673                                        loaded language      1
# 677                                                    NaN      0
# 679                                                    NaN      0
# 748                                           name-calling      1
# 749                 smears - loaded language - flag-waving      1
# 755                                                 smears      1
# 756                                             glittering      1
# 760                                                    NaN      0
# 764                                                 smears      1
# 767                                                    NaN      0
# 807                                            flag-waving      1
# 809                                                    NaN      0
# 865                                                    NaN      0
# 872                                                 smears      1
# 877                                                    NaN      0
# 878                               flag-waving - glittering      1
# 886                                                    NaN      0
# 889                                                    NaN      0
# 896                                                    NaN      0
# 911           causal over simplification - loaded language      1
# 912                                                    NaN      0
# 924                                   slogan - flag-waving      1

# %%
df = dataset[["tweetid", "tweet_text", "clean_tweet", "tech", "label"]].copy()
df = df.rename(columns={"clean_tweet": "text"})
df.head()
# Out:
#                tweetid  \
# 0   295735762505322497
# 1  1080873494227886086
# 2  1027481525506453504
# 3   417202038037299200
# 4   834074569673736193
#
#                                                                                                                                                  tweet_text  \
# 0                                                   النعيم أمي، وعين أمي، وقبلة أمي، فأكرمها يالله بطول العمر بالصحه والعافية وازرع في قلبها سعادة لاتزول ♥
# 1  RT @rood516: عرض الاجازه😍👌🏻1\nســــاعه\nقـــلم\nكــبك\nنظـــاره\nسبــحه 📿\nمـــيداليه\nخاتم\nمحفظه\nضمان الساعه لمدة سنه\nفقط ٢٢٠ريال\n🌟🌟\nواتس للطلب ا…
# 2                                                                                           RT @6FSH1_: مهما ضاق صدرك تذكر أن في ناس توهم بيسجلون بالجامعة.
# 3                                                                 RT @f450450: ﴿ياحي ياقيوم برحمتك أستغيث أصلح لي شأني كُلہ ولا تَكِلْني إلى نفسي طرفہ عين﴾
# 4                           RT @7744Qa: بعض البشر ، إذا وجد البديل نكر الجميل.\n#قروب_شوشي_للدعم \n#قروب_همس_المشاعر \n#قروب_سججات_بدوي \n#قروب_السمو_للدعم
#
#                                                                                                                            text  \
# 0                         النعيم أمي، وعين أمي، وقبلة أمي، فأكرمها يالله بطول العمر بالصحه والعافية وازرع في قلبها سعادة لاتزول
# 1  RT : عرض الاجازه1 ســــاعه قـــلم كــبك نظـــاره سبــحه مـــيداليه خاتم محفظه ضمان الساعه لمدة سنه فقط ٢٢٠ريال واتس للطلب ا…
# 2                                                                      RT : مهما ضاق صدرك تذكر أن في ناس توهم بيسجلون بالجامعة.
# 3                                                 RT : ﴿ياحي ياقيوم برحمتك أستغيث أصلح لي شأني كلہ ولا تكلني إلى نفسي طرفہ عين﴾
# 4                 RT : بعض البشر ، إذا وجد البديل نكر الجميل. قروب شوشي للدعم قروب همس المشاعر قروب سججات بدوي قروب السمو للدعم
#
#   tech  label
# 0  NaN      0
# 1  NaN      0
# 2  NaN      0
# 3  NaN      0
# 4  NaN      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2100 entries, 0 to 2099
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweetid     2100 non-null   int64
#  1   tweet_text  2100 non-null   object
#  2   text        2100 non-null   object
#  3   tech        202 non-null    object
#  4   label       2100 non-null   int32
# dtypes: int32(1), int64(1), object(3)
# memory usage: 74.0+ KB

# %%
# df.to_json("./data/to_label.json")
