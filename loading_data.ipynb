# %% [markdown]
# # Dataset Introduction - Loading

# %% [markdown]
# Just exploring the dataset and trying to capture any information from it. Goal: Split the data correctly

# %%
import pandas as pd
from datasets import Dataset

# %%
users = pd.read_csv("./data/saudi_arabia_112019_users_csv_hashed.csv")

# %%
users.head()
# Out:
#                                          userid  \
# 0  G4fT8DZWOhtFv3LOya6R2lu1eE1+wfBRSXAJTPBS1B4=
# 1  jfyXQBCFWEHB6bWgH2wpi4arPEXSV7dzBLUZSiqV0KY=
# 2    b1dryyC8OS8Xks0Zor23bh7yz3KtdyW9Q3258iWpw=
# 3  nKKzdTfPHiTC+eRAHIEiNCjeKuMJPboqg0Td315YqUM=
# 4   PFig14EPEbKgGsFqz4R9+m2ITf4qfx+kPv5MKTvMz4=
#
#                               user_display_name  \
# 0  G4fT8DZWOhtFv3LOya6R2lu1eE1+wfBRSXAJTPBS1B4=
# 1  jfyXQBCFWEHB6bWgH2wpi4arPEXSV7dzBLUZSiqV0KY=
# 2    b1dryyC8OS8Xks0Zor23bh7yz3KtdyW9Q3258iWpw=
# 3  nKKzdTfPHiTC+eRAHIEiNCjeKuMJPboqg0Td315YqUM=
# 4   PFig14EPEbKgGsFqz4R9+m2ITf4qfx+kPv5MKTvMz4=
#
#                                user_screen_name        user_reported_location  \
# 0  G4fT8DZWOhtFv3LOya6R2lu1eE1+wfBRSXAJTPBS1B4=                           NaN
# 1  jfyXQBCFWEHB6bWgH2wpi4arPEXSV7dzBLUZSiqV0KY=   هذا الحساب الجديد/ضاحية لبن
# 2    b1dryyC8OS8Xks0Zor23bh7yz3KtdyW9Q3258iWpw=                           NaN
# ...

# %%
users.tail()
# Out:
#                                             userid  \
# 5924   A6RBvyymjVzgILAaseyqpm1cVxlmHjQZIUjnuXhwRw=
# 5925                            886581466263670785
# 5926   ShALzmdoE8usiI+ZpOzTdIIGmwiHvqYcucJCljSlNw=
# 5927  DfKekaPNMan5x52LKnunFpnhywO01GdmGY9vrv0YjmY=
# 5928   yexCY6JigmPZ0o3DULpOZdknHKU8iNDhm0r0DLjb3Q=
#
#                                  user_display_name  \
# 5924   A6RBvyymjVzgILAaseyqpm1cVxlmHjQZIUjnuXhwRw=
# 5925                                       shahado
# 5926   ShALzmdoE8usiI+ZpOzTdIIGmwiHvqYcucJCljSlNw=
# 5927  DfKekaPNMan5x52LKnunFpnhywO01GdmGY9vrv0YjmY=
# 5928   yexCY6JigmPZ0o3DULpOZdknHKU8iNDhm0r0DLjb3Q=
#
#                                   user_screen_name   user_reported_location  \
# 5924   A6RBvyymjVzgILAaseyqpm1cVxlmHjQZIUjnuXhwRw=                 الرياض,
# 5925                                    Shahoda_om                 alriyadh
# 5926   ShALzmdoE8usiI+ZpOzTdIIGmwiHvqYcucJCljSlNw=         الدوحة, دولة قطر
# ...

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5929 entries, 0 to 5928
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   userid                    5929 non-null   object
#  1   user_display_name         5929 non-null   object
#  2   user_screen_name          5929 non-null   object
#  3   user_reported_location    3426 non-null   object
#  4   user_profile_description  4757 non-null   object
#  5   user_profile_url          311 non-null    object
#  6   follower_count            5929 non-null   int64
#  7   following_count           5929 non-null   int64
#  8   account_creation_date     5929 non-null   object
#  9   account_language          5929 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 463.3+ KB

# %%
import glob

# %%
tweets_data_paths = glob.glob("./data/*tweets_csv*.csv")

# %%
from tqdm.auto import tqdm

tweets_dfs = []

for tweet_data_path in tqdm(tweets_data_paths, total=len(tweets_data_paths)):
    print(f"Reading file {tweet_data_path}")
    tweets_dfs.append(pd.read_csv(tweet_data_path).drop_duplicates(["tweet_text"]))
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# Reading file ./data\saudi_arabia_112019_tweets_csv_hashed_1.csv
# C:\Users\ehhho\AppData\Local\Temp\ipykernel_26652\2710573969.py:7: DtypeWarning: Columns (15,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   tweets_dfs.append(pd.read_csv(tweet_data_path).drop_duplicates(["tweet_text"]))
# Reading file ./data\saudi_arabia_112019_tweets_csv_hashed_2.csv
# C:\Users\ehhho\AppData\Local\Temp\ipykernel_26652\2710573969.py:7: DtypeWarning: Columns (15,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   tweets_dfs.append(pd.read_csv(tweet_data_path).drop_duplicates(["tweet_text"]))
# Reading file ./data\saudi_arabia_112019_tweets_csv_hashed_3.csv
# C:\Users\ehhho\AppData\Local\Temp\ipykernel_26652\2710573969.py:7: DtypeWarning: Columns (15,19) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
tweets_dfs[0][["tweet_text"]].sample(40)
# Out:
#                                                 tweet_text
# 1752219   @_lHuc الله يطول بعمرها ويخليها لكم ويديم ضحكتها
# 4299237  RT @om3z2: @ewToau9YAjNGWUbTLKCp+5ZBDKP2e+MXV8...
# 1627655  @WomenToAware هنا طالع شوي حلو بس لن نرضخ للمت...
# 4490693  RT @amjadt25: حاول ان تجاهل..ان لأن #القمه_الع...
# 1448851  يا مقلب القلوب ثبت قلبي على دينك\n#الزززمن_الجميل
# 4252352  RT @HalahbO33: @tkII2EtuRM+71z2HsKJCkWw0lz4gCU...
# 55868    RT @anagtty1: 💥تخفيضات كبرى💥\n\nطقم نسائي 👟👜💁\...
# 3118418  RT @Tzq111: 🎶\n\n- من أين أتيت بهذِه القسوه؟! ...
# 2919454  RT @p_00_o: #وفاه_دانه_القحطاني\nصدمه💔 ،يارب ا...
# 955575   @qazialmthkar @c2d9Yz5ZI7UhpNzoLOdEsVN5amlFRJC...
# 1962865  RT @Iishahd_8: #صباحات_الهلال\nحيّ الصباح اللي...
# 1256866                                      @D_13567 ❤️❤️
# 916831   RT @baladinetwork: #بلدي\nنحو 600 قتيل مدني با...
# 3313031  RT @meck189: اللهم صل وسلم على نبينا محمدﷺ❤️\n...
# 4096066  RT @1li6l: ❥|❁\n\nㅤㅤ\nخَلفْ الكِتابَة مَشآعِر ...
# ...

# %%
tweets_dfs[1][["tweet_text"]].sample(40)
# Out:
#                                                 tweet_text
#
# 1703605  عساگ لغيري مغثه ☺ وسخيف ☺ وريحتك خايسه بعد☺♥ ا...
# 2019076  RT @ptk: ➋✮⇱فولو مي @ptk\n➌✮⇱فولو للي عمل رتوي...
# 1414014  # كل الحب للجميع و تمنياتنا لنادي الإتحاد بالت...
# 1193567  وَلَسَوْفَ يُعْطِيكَ رَبُّكَ فَتَرْضَى [الضحى:...
# 1740825  RT @Yosf99F: : للمتصلين  الآن .   \n\n➊ تبادل ...
# ...

# %% [markdown]
# All tweets are important. The most important of them are the political ones which was the reason why these accounts were suspended.

# %%
tweets = pd.concat(tweets_dfs, ignore_index=True)

# %%
tweets.head()
# Out:
#                tweetid                                      userid  \
# 0  1137497501194493952  PNn2yIomi1HIYwGdduEWQb+Jj4lX5NIHaMQmHrK6Y=
# 1  1170605961829990400                                  1121701880
# 2  1172783625445597184                                  1121701880
# 3  1122861301556969478                                   245029386
# 4  1107401207025410049                                   245029386
#
#                             user_display_name  \
# 0  PNn2yIomi1HIYwGdduEWQb+Jj4lX5NIHaMQmHrK6Y=
# 1                             ấłřấŝŝễễħ_48🕊ḁѦ
# 2                             ấłřấŝŝễễħ_48🕊ḁѦ
# 3                         🦋 الًٓــٌٓريــٓـم 🦋
# 4                         🦋 الًٓــٌٓريــٓـم 🦋
#
#                              user_screen_name     user_reported_location  \
# 0  PNn2yIomi1HIYwGdduEWQb+Jj4lX5NIHaMQmHrK6Y=  المملكة العربية السعودية
# 1                                   suuny2010    Najran🕊 Riyadh🕊🇸🇦lbri🇴🇲
# ...

# %%
tweets.tail()
# Out:
#                      tweetid     userid user_display_name user_screen_name  \
# 22290433  394052321287479296  973670437     مجلس الداعمين         w3tasimo
# 22290434  406107957173452800  973670437     مجلس الداعمين         w3tasimo
# 22290435  333702318363136000  973670437     مجلس الداعمين         w3tasimo
# 22290436  319848902004183040  973670437     مجلس الداعمين         w3tasimo
# 22290437  338741745997205505  973670437     مجلس الداعمين         w3tasimo
#
#          user_reported_location  \
# 22290433                    NaN
# 22290434                    NaN
# 22290435                    NaN
# 22290436                    NaN
# 22290437                    NaN
#
#                                    user_profile_description user_profile_url  \
# 22290433  ‏‏‏‏‏‏‏‏مجلس الداعمين للثورة السورية - الكويت ...              NaN
# 22290434  ‏‏‏‏‏‏‏‏مجلس الداعمين للثورة السورية - الكويت ...              NaN
# 22290435  ‏‏‏‏‏‏‏‏مجلس الداعمين للثورة السورية - الكويت ...              NaN
# ...

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22290438 entries, 0 to 22290437
# Data columns (total 30 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   tweetid                   int64
#  1   userid                    object
#  2   user_display_name         object
#  3   user_screen_name          object
#  4   user_reported_location    object
#  5   user_profile_description  object
#  6   user_profile_url          object
#  7   follower_count            int64
#  8   following_count           int64
#  9   account_creation_date     object
#  10  account_language          object
#  11  tweet_language            object
#  12  tweet_text                object
#  13  tweet_time                object
#  14  tweet_client_name         object
#  15  in_reply_to_userid        object
#  16  in_reply_to_tweetid       float64
#  17  quoted_tweet_tweetid      float64
#  18  is_retweet                bool
#  19  retweet_userid            object
# ...

# %%
# tweets.to_pickle("data/tweets.pickle")
